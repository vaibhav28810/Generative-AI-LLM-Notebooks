# %%
# !pip install ctransformers[cuda]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 28.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 36.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.8/417.8 MB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 845.8/845.8 kB 59.7 MB/s eta 0:00:00
# ...

# %%
from ctransformers import AutoModelForCausalLM
def colab_print(text, max_width = 120):
  words = text.split()
  line = ""
  for word in words:
    if len(line) + len(word) + 1 > max_width:
      print(line)
      line = ""
    line += word + " "
  print (line)

# %%
from ctransformers import AutoModelForCausalLM
llm = AutoModelForCausalLM.from_pretrained("TheBloke/Amethyst-13B-Mistral-GGUF", model_file="amethyst-13b-mistral.Q4_K_M.gguf", model_type = "mistral", gpu_layers = 50)
# Out:
# ...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
colab_print(llm("Give me a paragraph that describes a blizzard", max_new_tokens = 2048, temperature = 0.9, top_k = 55, top_p = 0.93, repetition_penalty = 1.2))
# Out:
# . The howling wind and icy flakes created an otherworldly atmosphere, blanketing everything in a thick mantle of snow.
# The sky darkened prematurely as the storm intensified, reducing visibility to mere feet. Drifts piled up against
# buildings and vehicles alike, causing even the most experienced drivers to lose their way. People huddled indoors or
# struggled through the deepening drifts, their faces stinging from the biting cold and windburn. Tree branches groaned
# under the weight of ice-coated snow before snapping off with a resounding crack, adding more debris to an already
# chaotic landscape. The blizzard raged on relentlessly, transforming familiar surroundings into a bleak and inhospitable
# wasteland.
